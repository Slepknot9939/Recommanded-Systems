# %%
import pandas as pd
import numpy as np


df=pd.read_csv('book.csv',engine='python')
df.head()
# Out:
#    Unnamed: 0  User.ID                                         Book.Title  \
# 0           1   276726                                Classical Mythology
# 1           2   276729                                       Clara Callan
# 2           3   276729                               Decision in Normandy
# 3           4   276736  Flu: The Story of the Great Influenza Pandemic...
# 4           5   276737                             The Mummies of Urumchi
#
#    Book.Rating
# 0            5
# 1            3
# 2            6
# 3            8
# 4            6

# %%
data=df.copy()

# %%
data.iloc[:,1:]
# Out:
#       User.ID                                         Book.Title  Book.Rating
# 0      276726                                Classical Mythology            5
# 1      276729                                       Clara Callan            3
# 2      276729                               Decision in Normandy            6
# 3      276736  Flu: The Story of the Great Influenza Pandemic...            8
# 4      276737                             The Mummies of Urumchi            6
# ...       ...                                                ...          ...
# 9995   162121       American Fried: Adventures of a Happy Eater.            7
# 9996   162121                              Cannibal In Manhattan            9
# 9997   162121                    How to Flirt: A Practical Guide            7
# 9998   162121                                           Twilight            8
# 9999   162129                       Kids Say the Darndest Things            6
#
# [10000 rows x 3 columns]

# %%
data1=data.rename({'User.ID':'uid','Book.Title':'title','Book.Rating':'ratings'},axis=1)

# %%
data1.iloc[:,1:]
# Out:
#          uid                                              title  ratings
# 0     276726                                Classical Mythology        5
# 1     276729                                       Clara Callan        3
# 2     276729                               Decision in Normandy        6
# 3     276736  Flu: The Story of the Great Influenza Pandemic...        8
# 4     276737                             The Mummies of Urumchi        6
# ...      ...                                                ...      ...
# 9995  162121       American Fried: Adventures of a Happy Eater.        7
# 9996  162121                              Cannibal In Manhattan        9
# 9997  162121                    How to Flirt: A Practical Guide        7
# 9998  162121                                           Twilight        8
# 9999  162129                       Kids Say the Darndest Things        6
#
# [10000 rows x 3 columns]

# %%
data1=data1.drop('Unnamed: 0',axis=1)

# %%
data1.head()
# Out:
#       uid                                              title  ratings
# 0  276726                                Classical Mythology        5
# 1  276729                                       Clara Callan        3
# 2  276729                               Decision in Normandy        6
# 3  276736  Flu: The Story of the Great Influenza Pandemic...        8
# 4  276737                             The Mummies of Urumchi        6

# %%
Average_ratings=pd.DataFrame(data1.groupby('title')['ratings'].mean())
Average_ratings.head()
# Out:
#                                                     ratings
# title
#  Jason, Madison &amp                                    8.0
#  Other Stories;Merril;1985;McClelland &amp              6.0
#  Repairing PC Drives &amp                               4.0
# '48                                                     7.0
# 'O Au No Keia: Voices from Hawai'I's Mahu and T...      8.0

# %%
Average_ratings['Total Ratings']=pd.DataFrame(data1.groupby('title')['ratings'].count())
Average_ratings.head()
# Out:
#                                                     ratings  Total Ratings
# title
#  Jason, Madison &amp                                    8.0              1
#  Other Stories;Merril;1985;McClelland &amp              6.0              1
#  Repairing PC Drives &amp                               4.0              1
# '48                                                     7.0              1
# 'O Au No Keia: Voices from Hawai'I's Mahu and T...      8.0              1

# %%
movie_user=data1.pivot_table(index='uid',columns='title',values='ratings')
movie_user.head()
# Out:
# title   Jason, Madison &amp   Other Stories;Merril;1985;McClelland &amp  \
# uid
# 8                       NaN                                         NaN
# 9                       NaN                                         NaN
# 10                      NaN                                         NaN
# 12                      NaN                                         NaN
# 14                      NaN                                         NaN
#
# title   Repairing PC Drives &amp  '48  \
# uid
# 8                            NaN  NaN
# 9                            NaN  NaN
# 10                           NaN  NaN
# 12                           NaN  NaN
# 14                           NaN  NaN
#
# title  'O Au No Keia: Voices from Hawai'I's Mahu and Transgender Communities  \
# uid
# 8                                                    NaN
# 9                                                    NaN
# 10                                                   NaN
# ...

# %%
correlations=movie_user.corrwith(data1)
correlations.head()

# %%
recommendation=pd.DataFrame(correlations,columns=['Correlations'])
recommendation.dropna(inplace=True)
recommendation=recommendation.join(Average_ratings['Total Ratings'])
recommendation.head()
# Out:
# Empty DataFrame
# Columns: [Correlations, Total Ratings]
# Index: []

# %%
len(data1.uid.unique())
# Out:
# 2182

# %%
len(data1.bt.unique())
# Out:
# 9659

# %%
len(data1.br.unique())
# Out:
# 10

# %%
data1[data1.duplicated()].shape
# Out:
# (2, 3)

# %%
data1=data1.drop_duplicates()

# %%
data1[data1.duplicated()].shape
# Out:
# (0, 3)

# %%
data1.dtypes
# Out:
# uid     int64
# bt     object
# br      int64
# dtype: object

# %%
data1.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-710ca0d3db0c> in <module>
# ----> 1 data1.head()
#
# NameError: name 'data1' is not defined

# %%
import seaborn as sns
sns.swarmplot(x='uid',y='bt',data=data1)
plt.show()

# %%
user_data_df=data1.pivot(index='uid',columns='bt',values='br').reset_index(drop=True)
